# %%
  import pandas as pd
  import numpy as np
  import matplotlib.pyplot as plt
  from matplotlib.ticker import FuncFormatter
  from functions import *

# %% [markdown]
# ### All the heavy lifting is being done from the functions in the <em><strong>functions.py</strong></em> file. It can be refrenced for clarification.

# %% [markdown]
# # Reding in the data

# %%
# now reading locally
data_url = "data/Louisville_Metro_KY_-_Employee_Salary_Data.csv"
df = process_salary_data(data_url)
df.head(1)
# df.to_csv('data/ot_added_all.csv')
# Out:
#       CalYear      Employee_Name                          Department  \
# 9291     2023  Ingram, Lydia Ann  Louisville Metro Police Department
#
#                             jobTitle  Annual_Rate  Regular_Rate  \
# 9291  LMPD Service Center Technician     41995.20          0.00
#
#       Overtime_Rate  Incentive_Allowance  Other  YTD_Total  ObjectId  Hr_Rate  \
# 9291         151.43                 0.00   0.00     151.43      9292     0.00
#
#       Ot_Rate  Hr_Worked
# 9291     0.00        inf

# %% [markdown]
# # 2023

# %%
a23 = Dep_yearly(2023)
a23.head(3)
# Out:
#     CalYear                          Department   YTD_Total
# 21     2023  Louisville Metro Police Department 83367893.59
# 19     2023                     Louisville Fire 29064660.74
# 7      2023           Department of Corrections 21325721.53

# %% [markdown]
# This graphs the annual salary spend by department by a given year. Here is the data for 2023.

# %%
a_dep(a23)

# %% [markdown]
# This will display all employees whom have averages 66+ hours a week.
# <br>
# The weekly hours worked are in the far right column.
# * Determine the hourly rate (column Hr_Rate):
# * Hr_Rate = Regular_Rate / 2080
# * Calculate the overtime rate (column Ot_Rate):
# * Ot_Rate = Hr_Rate * 1.5
# * Calculate the number of overtime hours:
# * Overtime_Hours = Overtime_Rate / Ot_Rate
# * Distribute evenly over 52 weeks:
# * Weekly_Overtime_Hours = Overtime_Hours
# * Calculate the weekly average:
# * Weekly_Average = Weekly_Overtime_Hours + 40
# <br>
# This is not accounting for vacations off time ect. So we would expect some weeks have higher and lower hours.

# %%
df23 = OT(2023)
df23.head()
# Out:
#        CalYear      Employee_Name                          Department  \
# 9291      2023  Ingram, Lydia Ann  Louisville Metro Police Department
# 12002     2023    Watson, Danny W                  Parks & Recreation
# 8740      2023    Herndon, Adam B                     Louisville Fire
# 7579      2023    Murphy, Paul P.                     Louisville Fire
# 6821      2023  Hudson, Daryell W                     Louisville Fire
#
#                              jobTitle  Annual_Rate  Regular_Rate  \
# 9291   LMPD Service Center Technician     41995.20          0.00
# 12002    Golf Operations Supervisor I     44075.20          0.00
# 8740     Fire Apparatus Operator 56hr     67362.05      29236.09
# 7579     Fire Apparatus Operator 56hr     67362.05      28539.73
# 6821     Fire Apparatus Operator 56hr     67362.05      25227.89
#
#        Overtime_Rate  Incentive_Allowance   Other  YTD_Total  ObjectId  \
# 9291          151.43                 0.00    0.00     151.43      9292
# ...

# %%
OT_E(df23)

# %%
plot_department_counts(df23)
